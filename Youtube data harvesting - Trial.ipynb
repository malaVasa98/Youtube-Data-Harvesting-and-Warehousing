# %%
# !pip install google-api-python-client
# Out:
# ...
#   Obtaining dependency information for google-api-python-client from https://files.pythonhosted.org/packages/fc/8e/c62e3ebc586e93a49f4276131eed57d11d2dc9af123dd532f259d8ed25b0/google_api_python_client-2.127.0-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for httplib2<1.dev0,>=0.19.0 from https://files.pythonhosted.org/packages/a8/6c/d2fbdaaa5959339d53ba38e94c123e4e84b8fbc4b84beb0e70d7c1608486/httplib2-0.22.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 from https://files.pythonhosted.org/packages/9e/8d/ddbcf81ec751d8ee5fd18ac11ff38a0e110f39dfbf105e6d9db69d556dd0/google_auth-2.29.0-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for google-auth-httplib2<1.0.0,>=0.2.0 from https://files.pythonhosted.org/packages/be/8a/fe34d2f3f9470a27b01c9e76226965863f153d5fbe276f83608562e49c04/google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata
# ...

# %%
import googleapiclient.discovery
api_service_name = "youtube"
api_version = "v3"
api_key = "AIzaSyBNat7Bbww1nvJzbUt1686oggHQOrQVtGs"
youtube = googleapiclient.discovery.build(api_service_name, api_version,developerKey=api_key)

# %%
def channel_data(c_id):
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=c_id
    )
    response = request.execute()
    data = {"Channel_name":response['items'][0]['snippet']['title'],
            "Channel_id":c_id,
            "Channel_description":response['items'][0]['snippet']['description'],
            "Channel_published_at":response['items'][0]['snippet']['publishedAt'],
            "Playlist_id":response['items'][0]['contentDetails']['relatedPlaylists']['uploads'],
            "Subscription_Count":response['items'][0]['statistics']['subscriberCount'],
            "Channel_views":response['items'][0]['statistics']['viewCount'],
            "Channel_videos_count":response['items'][0]['statistics']['videoCount']
        
    }
    return data

# %%
# Output of the above function where a sample Channel ID is taken 
channel_data('UCASGyre6VNuPsF5f9f9nm8g')
# Out:
# {'channel_name': 'LOVEBUSTER',
#  'channel_id': 'UCASGyre6VNuPsF5f9f9nm8g',
#  'desciption_channel': 'Movie-like love is not a fantasy. It’s real. And you deserve it. \n\nLOVEBUSTER brings you romantic stories and heartfelt moments. They may seem too good to be true. But anything we dare to dream of can happen. The question is, do you allow yourself to think of something unbelievable and act upon it?\n\nWe hope to inspire you. To motivate you to believe in true love. And to never lose your spark.\n\nBecause love is the greatest gift any person can wish for. \n\nJoin the LOVEBUSTER community to enjoy new romantic stories, endearing content, and people who love love as much as you.\n',
#  'channel_published_at': '2022-10-20T12:41:45.733808Z',
#  'channel_pid': 'UUASGyre6VNuPsF5f9f9nm8g',
#  'channel_subscnt': '1140000',
#  'channel_view_count': '309328639',
#  'channel_video_count': '225'}

# %%
# Creating the Channel data in the form of a dictionary where the keys are the columns of the sql table
## and the values are the channel details of 10 different channels embedded as a list 
Channel_name = []
Channel_id = []
Channel_description = []
Channel_published_at = []
Playlist_id = []
Subscription_Count = []
Channel_views = []
Channel_videos_count = []
count = 1
from datetime import datetime
while count<=10:
    chan_id = input('Enter a Channel id: ')
    data_ch = channel_data(chan_id)
    Channel_name.append(data_ch["Channel_name"])
    Channel_id.append(data_ch["Channel_id"])
    Channel_description.append(data_ch["Channel_description"])
    Channel_published_at.append(data_ch["Channel_published_at"])
    Playlist_id.append(data_ch["Playlist_id"])
    Subscription_Count.append(int(data_ch["Subscription_Count"]))
    Channel_views.append(int(data_ch["Channel_views"]))
    #Channel_videos_count.append(int(data_ch["Channel_videos_count"]))
    count += 1
Channel_data = {
    "Channel_name":Channel_name,
    "Channel_id":Channel_id,
    "Channel_description":Channel_description,
    "Channel_published_at":Channel_published_at,
    "Playlist_id":Playlist_id,
    "Subscription_Count":Subscription_Count,
    "Channel_views":Channel_views,
    #"Channel_videos_count":Channel_videos_count
}
import json
with open('Channel_data.json','w') as j_f:
    json.dump(Channel_data,j_f)
# Out:
# Enter a Channel id: UCASGyre6VNuPsF5f9f9nm8g
# Enter a Channel id: UC14aFPpH4jF3FfRQZojCfeg
# Enter a Channel id: UCaXLqAY222QioBkYyYVxxTw
# Enter a Channel id: UCp3HX2PhW0FmEUX5ueS1HqA
# Enter a Channel id: UCeng9rxwI8UwRyBouL2RImw
# Enter a Channel id: UCwKOXA_I80OH095LdLBDXsA
# Enter a Channel id: UCTLTttKxRHZvmY-396ewwaA
# Enter a Channel id: UC887NJ1_gm2nuAy7lS8SvmA
# Enter a Channel id: UCl6_axGwQ0p8x5H4yP67M9A
# Enter a Channel id: UCQo0RqaoE-112MXYhLulKFg

# %%
import json
with open('Channel_data.json') as ch:
    Channel_data = json.load(ch)

# %%
with open('Channel_data.json') as ch:
    Channel_data = json.load(ch)
Channel_data.keys()
# Out:
# dict_keys(['Channel_name', 'Channel_id', 'Channel_description', 'Channel_published_at', 'Playlist_id', 'Subscription_Count', 'Channel_views'])

# %%
# In JSON format, the details of Channel_published_at couldn't be saved in datetime datatype
## and we saved it in string datatype. The method converts each entries into datetime format
from datetime import datetime
Pub = Channel_data["Channel_published_at"]
Pub_new = []
for date_ in Pub:
    format_string = ["%Y-%m-%dT%H:%M:%S.%fZ","%Y-%m-%dT%H:%M:%SZ"]
    for format_str in format_string:
        try:
            formatted_date = datetime.strptime(date_,format_str)
            break
        except ValueError:
            continue
    Pub_new.append(formatted_date)

# Updating the dictionary
Channel_data["Channel_published_at"] = Pub_new

# %%
import pandas as pd
df_x = pd.DataFrame(Channel_data)
df_x.Playlist_id
print(Channel_data['Playlist_id'])
# Out:
# ['UUASGyre6VNuPsF5f9f9nm8g', 'UU14aFPpH4jF3FfRQZojCfeg', 'UUaXLqAY222QioBkYyYVxxTw', 'UUp3HX2PhW0FmEUX5ueS1HqA', 'UUeng9rxwI8UwRyBouL2RImw', 'UUwKOXA_I80OH095LdLBDXsA', 'UUTLTttKxRHZvmY-396ewwaA', 'UU887NJ1_gm2nuAy7lS8SvmA', 'UUl6_axGwQ0p8x5H4yP67M9A', 'UUQo0RqaoE-112MXYhLulKFg']

# %%
df_x
# Out:
#            Channel_name                Channel_id  \
# 0            LOVEBUSTER  UCASGyre6VNuPsF5f9f9nm8g
# 1       Words of Wisdom  UC14aFPpH4jF3FfRQZojCfeg
# 2     Finest Art Luxury  UCaXLqAY222QioBkYyYVxxTw
# 3  DramatizeMe Special   UCp3HX2PhW0FmEUX5ueS1HqA
# 4  Adibasi Family Vlogs  UCeng9rxwI8UwRyBouL2RImw
# 5            Illumeably  UCwKOXA_I80OH095LdLBDXsA
# 6        Weekly Wrap Up  UCTLTttKxRHZvmY-396ewwaA
# 7        Re Productions  UC887NJ1_gm2nuAy7lS8SvmA
# 8             MK Fun Tv  UCl6_axGwQ0p8x5H4yP67M9A
# 9   ROBIN TECH OFFICIAL  UCQo0RqaoE-112MXYhLulKFg
#
#                                  Channel_description  \
# 0  Movie-like love is not a fantasy. It’s real. A...
# 1  Hi I am Shalender. This channel is made with i...
# 2   I'd love to share with u,  all that I enjoy d...
# 3  This is your safe space. \n\nSo, when you need...
# 4  Welcome to the heartwarming world of the 'Adib...
# 5  Illumeably has one goal: to spread positivity ...
# ...

# %%
# Now to get the video ids for every videos of the Channel using the Playlist id of each channel
video_id = []
Playlist_id_vid = []
for i in range(len(Channel_data["Playlist_id"])):
    next_page_token=None
    while True:
        request = youtube.playlistItems().list(
              part="snippet,contentDetails",
              playlistId=Channel_data["Playlist_id"][i],
              maxResults=50,
              pageToken=next_page_token
            )
        response = request.execute()
        l_a = []
        for item in response['items']:
            video_id.append(item['contentDetails']['videoId'])
            l_a.append(item['contentDetails']['videoId'])
        next_page_token = response.get('nextPageToken')
        Playlist_id_vid = Playlist_id_vid + [Channel_data["Playlist_id"][i] for count in range(len(l_a))]
        if not next_page_token:
            break

# %%
print(len(Playlist_id_vid))
# Out:
# 1148

# %%
# video name
response['items'][0]['snippet']['title']
# video description
response['items'][0]['snippet']['description']
# published at
response['items'][0]['snippet']['publishedAt']
#view count
response['items'][0]['statistics']['viewCount']
# like count
response['items'][0]['statistics']['likeCount']
# favorite count
response['items'][0]['statistics']['favoriteCount']
# Comment count
response['items'][0]['statistics']['commentCount']
# Duration
response['items'][0]['contentDetails']['duration']
# Thumbnail
response['items'][0]['snippet']['thumbnails']['default']['url']
# caption status
response['items'][0]['contentDetails']['caption']
# Out:
# 'false'

# %%
def video_data(idx): 
    request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=idx
            )
    response = request.execute()
    vid_data = {
        "Video_name":response['items'][0]['snippet']['title'],
        "Video_description":response['items'][0]['snippet']['description'],
        "Video_Published_at":response['items'][0]['snippet']['publishedAt'],
        "Video_view_count":response['items'][0]['statistics']['viewCount'],
        "Video_like_count":response['items'][0]['statistics']['likeCount'] if 'likeCount' in response['items'][0]['statistics'].keys() else None,
        "Video_favorite_count":response['items'][0]['statistics']['favoriteCount'],
        "Video_comment_count":response['items'][0]['statistics']['commentCount'],
        "Video_duration":response['items'][0]['contentDetails']['duration'],
        "Video_thumbnail":response['items'][0]['snippet']['thumbnails']['default']['url'],
        "Video_caption_status":"Not Available" if response['items'][0]['contentDetails']['caption']=='false' else "Available"
    }
    return vid_data

# %%
# Getting the video details for each video id 
Video_name = []
Video_description = []
Video_Published_at = []
Video_view_count = []
Video_like_count = []
Video_favorite_count = []
Video_comment_count = []
Video_duration = []
Video_thumbnail = []
Video_caption_status = []
for idx in video_id:
    data_v = video_data(idx)
    Video_name.append(data_v["Video_name"])
    Video_description.append(data_v["Video_description"])
    Video_Published_at.append(data_v["Video_Published_at"])
    Video_view_count.append(int(data_v["Video_view_count"]))
    Video_like_count.append(int(data_v["Video_like_count"]) if data_v["Video_like_count"]!=None else data_v["Video_like_count"])
    Video_favorite_count.append(int(data_v["Video_favorite_count"]))
    Video_comment_count.append(int(data_v["Video_comment_count"]))
    Video_duration.append(data_v["Video_duration"])
    Video_thumbnail.append(data_v["Video_thumbnail"])
    Video_caption_status.append(data_v["Video_caption_status"])

# %%
Video_data = {
    "Playlist_id":Playlist_id_vid,
    "Video_id":video_id,
    "Video_name":Video_name,
    "Video_description":Video_description,
    "Video_Published_at":Video_Published_at,
    "Video_view_count":Video_view_count,
    "Video_like_count":Video_like_count,
    "Video_favorite_count":Video_favorite_count,
    "Video_comment_count":Video_comment_count,
    "Video_duration":Video_duration,
    "Video_thumbnail":Video_thumbnail,
    "Video_caption_status":Video_caption_status
}

# %%
import json
with open('Video_data.json','w') as v_du:
    json.dump(Video_data,v_du)

# %%
import json
with open("Video_data.json") as jfi:
    Video_data = json.load(jfi)

# %%
import pandas as pd
dfd = pd.DataFrame(Video_data)
dfd
# Out:
#                    Playlist_id     Video_id  \
# 0     UUASGyre6VNuPsF5f9f9nm8g  NoxxY2UX9Hg
# 1     UUASGyre6VNuPsF5f9f9nm8g  zP_b4Xxd2vc
# 2     UUASGyre6VNuPsF5f9f9nm8g  AkfXvp4d86A
# 3     UUASGyre6VNuPsF5f9f9nm8g  0QiWQ9ycADg
# 4     UUASGyre6VNuPsF5f9f9nm8g  N-RqavKcRD0
# ...                        ...          ...
# 1143  UUQo0RqaoE-112MXYhLulKFg  2HUqNPgg50M
# 1144  UUQo0RqaoE-112MXYhLulKFg  LzNlJe6mVpM
# 1145  UUQo0RqaoE-112MXYhLulKFg  GdgJo2ZHe5M
# 1146  UUQo0RqaoE-112MXYhLulKFg  BfvAoCnm2hI
# 1147  UUQo0RqaoE-112MXYhLulKFg  Jx4DC4saM4Y
#
#                                              Video_name  \
# 0        I Fell For The Girl I Arrested  | @LoveBuster_
# 1     I Betrayed My BF To Help A Sick Man | @LoveBus...
# 2     Millionaire With Amnesia Falls For Maid | @Lov...
# 3     I Fell In Love With My Office Rival | @LoveBus...
# 4         I Found My Love In A Car Crash | @LoveBuster_
# ...                                                 ...
# ...

# %%
# Now to get the comment details of each video using their video ids
Comment_id = []
Video_id_com = []
Comment_text = []
Comment_author = []
Comment_published_at = []
for i in range(len(Video_data["Video_id"])):
    # This is because videos with O comments have no comment IDs 
    if Video_data["Video_comment_count"][i]!=0: 
        request = youtube.commentThreads().list(
            part="id,snippet",
            videoId=Video_data["Video_id"][i],
            maxResults=100
            )
        response = request.execute()
        L_a = []
        for comm in response['items']:
            Comment_id.append(comm['id'])
            L_a.append(comm['id'])
            Comment_text.append(comm['snippet']['topLevelComment']['snippet']['textDisplay'])
            Comment_author.append(comm['snippet']['topLevelComment']['snippet']['authorDisplayName'])
            Comment_published_at.append(comm['snippet']['topLevelComment']['snippet']['publishedAt'])
        Video_id_com = Video_id_com +[Video_data["Video_id"][i] for count in range(len(L_a))]

# %%
print(len(Comment_published_at))
print(len(Video_id_com))
# Out:
# 90906
# 90906

# %%
Comment_data = {
    "Comment_id":Comment_id,
    "Video_id":Video_id_com,
    "Comment_text":Comment_text,
    "Comment_author":Comment_author,
    "Comment_published_at":Comment_published_at
}

# %%
df_co = pd.DataFrame(Comment_data)
df_co
# Out:
#                        Comment_id     Video_id  \
# 0      UgxKehGRFER04i0dlC54AaABAg  NoxxY2UX9Hg
# 1      UgwT5uHMDfpKABz9Aqp4AaABAg  NoxxY2UX9Hg
# 2      Ugxxn73sNUd36ioebX14AaABAg  NoxxY2UX9Hg
# 3      Ugx51nxjXONaTrQYdAx4AaABAg  NoxxY2UX9Hg
# 4      UgzOhn8nwTCfID1-lQd4AaABAg  NoxxY2UX9Hg
# ...                           ...          ...
# 90901  Ugy3MFbPMRfe9IGJ1aF4AaABAg  Jx4DC4saM4Y
# 90902  UgxGx_OeJEaHGj9mKEZ4AaABAg  Jx4DC4saM4Y
# 90903  UgyI5POB66YKAMwnlkp4AaABAg  Jx4DC4saM4Y
# 90904  UgyXfDvg9SrAgFdPDBN4AaABAg  Jx4DC4saM4Y
# 90905  Ugz_r1X9beeRpUEEyMZ4AaABAg  Jx4DC4saM4Y
#
#                                          Comment_text  \
# 0           Is home a place or the people around you?
# 1            @lovebuster<br>Lead actress name please?
# 2         I slept in the garage boom I fell in love 😂
# 3            WE DEMAND MORE VIDEOS OF THE GOOD GUYYY!
# 4                                OK. THIS WAS AMAZING
# ...                                               ...
# ...

# %%
import json
with open('Comment_data.json','w') as com_f:
    json.dump(Comment_data,com_f)

# %%
# Comment text
response['items'][0]['snippet']['topLevelComment']['snippet']['textDisplay']
# Comment Author
response['items'][0]['snippet']['topLevelComment']['snippet']['authorDisplayName']
# Comment_Published_at
response['items'][0]['snippet']['topLevelComment']['snippet']['publishedAt']
# Out:
# '2024-04-29T03:49:31Z'

# %%
response['items'][0]['id']==response['items'][0]['snippet']['topLevelComment']['id']
# Out:
# True

# %%
Video_data["Video_comment_count"][2]
# Out:
# 310

# %%
from sqlalchemy import create_engine, Column, Integer, String, DateTime, Text
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

# %%
Chan_playlist_id = []
for c_id in Channel_data["Channel_id"]:
    data_ch = channel_data(c_id)
    Chan_playlist_id.append(data_ch["Playlist_id"])

# %%
Chan_playlist_id
# Out:
# ['UUASGyre6VNuPsF5f9f9nm8g',
#  'UU14aFPpH4jF3FfRQZojCfeg',
#  'UUaXLqAY222QioBkYyYVxxTw',
#  'UUp3HX2PhW0FmEUX5ueS1HqA',
#  'UUeng9rxwI8UwRyBouL2RImw',
#  'UUwKOXA_I80OH095LdLBDXsA',
#  'UUTLTttKxRHZvmY-396ewwaA',
#  'UU887NJ1_gm2nuAy7lS8SvmA',
#  'UUl6_axGwQ0p8x5H4yP67M9A',
#  'UUQo0RqaoE-112MXYhLulKFg']

# %%
for i,j in zip(Chan_playlist_id,Channel_data["Playlist_id"]):
    a = (i==j)
    print(a)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
